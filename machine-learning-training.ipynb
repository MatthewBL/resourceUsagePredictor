# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.feature_selection import SelectKBest, f_regression, mutual_info_regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import joblib
import re

# %%
def preprocess_data():
    # Read the individual and collective monitoring CSV files
    individual_df = pd.read_csv('processed_individual_monitoring.csv')
    collective_df = pd.read_csv('processed_collective_monitoring.csv')
    
    # Recalculate the Identifier column in the collective_df
    collective_df['Identifier'] = collective_df['URI'].str.strip() + '_' + collective_df['Method'].str.strip() + '_' + collective_df['Pricing'].str.strip()

    # Merge the DataFrames on the Identifier column
    merged_df = pd.merge(collective_df, individual_df, on='Identifier', suffixes=('', '_Individual'))
    
    # Calculate the deviation in Elapsed Time
    merged_df['Elapsed Time Deviation'] = ((merged_df['Elapsed Time'] - merged_df['Elapsed Time_Individual']) / merged_df['Elapsed Time_Individual']) * 100
    
    # Remove the categorical columns and the Elapsed Time_Individual column
    numerical_df = merged_df.drop(columns=['URI', 'Method', 'Identifier', 'Elapsed Time_Individual'])

    return numerical_df

# %%
def train_and_export_model(target_column, model_type='linear', k_best_features=5):
    numerical_df = preprocess_data()

    # One-hot encode the "Pricing" attribute
    pricing_dummies = pd.get_dummies(numerical_df['Pricing'], prefix='Pricing')
    numerical_df = pd.concat([numerical_df, pricing_dummies], axis=1)

    # Ensure all required Pricing columns exist
    required_pricing_columns = ["Pricing_ BASIC", "Pricing_ GOLD", "Pricing_ PLATINUM", "Pricing_ null"]
    for col in required_pricing_columns:
        if col not in numerical_df.columns:
            numerical_df[col] = 0

    numerical_df = numerical_df.drop(columns=['Pricing'])

    # Group by Timestamp and aggregate the individual numerical values
    aggregated_df = numerical_df.groupby('Timestamp').agg(['sum', 'mean', 'max', 'min'])

    # Flatten the MultiIndex columns
    aggregated_df.columns = ['_'.join(col).strip() for col in aggregated_df.columns.values]

    # Count the number of rows for each Timestamp and add it as a new attribute
    row_counts = numerical_df.groupby('Timestamp').size()
    aggregated_df['row_count'] = row_counts

    # Drop the Timestamp column
    aggregated_df = aggregated_df.reset_index(drop=True)

    # Ensure the target column is not dropped
    if target_column not in aggregated_df.columns:
        raise ValueError(f"Target column '{target_column}' not found in the data.")

    # Select all columns except those that include '_Individual' and the target_column
    columns_to_drop = [col for col in aggregated_df.columns if '_Individual' not in col and 'Pricing' not in col and col != target_column and 'Elapsed Time' not in col and col != 'row_count']
    filtered_df = aggregated_df.drop(columns=columns_to_drop)

    # Separate features and target
    X = filtered_df.drop(columns=[target_column])
    y = filtered_df[target_column]

    # Save the order of columns used during training
    with open(f'columns_order_{target_column}_{model_type}.txt', 'w') as f:
        f.write('\n'.join(X.columns))

    # Select the feature selection method based on the model type
    if model_type == 'linear':
        selector = SelectKBest(score_func=f_regression, k=k_best_features)
    elif model_type in ['random_forest', 'svm', 'gradient_boosting', 'knn', 'decision_tree']:
        selector = SelectKBest(score_func=mutual_info_regression, k=k_best_features)
    else:
        raise ValueError(f"Model type '{model_type}' is not supported.")

    # Feature selection
    X_new = selector.fit_transform(X, y)

    # Get the selected feature names and their scores
    selected_features = X.columns[selector.get_support()]
    feature_scores = selector.scores_[selector.get_support()]

    # Create a DataFrame for the selected features and their scores
    feature_importance_df = pd.DataFrame({
        'Feature': selected_features,
        'Score': feature_scores
    })

    # Sort the DataFrame by scores in descending order
    feature_importance_df = feature_importance_df.sort_values(by='Score', ascending=False)

    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)

    # Select the model based on the parameter
    if model_type == 'linear':
        model = LinearRegression()
    elif model_type == 'random_forest':
        model = RandomForestRegressor(random_state=42)
    elif model_type == 'svm':
        model = SVR()
    elif model_type == 'gradient_boosting':
        model = GradientBoostingRegressor(random_state=42)
    elif model_type == 'knn':
        model = KNeighborsRegressor()
    elif model_type == 'decision_tree':
        model = DecisionTreeRegressor(random_state=42)
    else:
        raise ValueError(f"Model type '{model_type}' is not supported.")

    # Train the model
    model.fit(X_train, y_train)

    # Predict on the test set
    y_pred = model.predict(X_test)

    # Evaluate the model
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)

    # Display the metrics
    print("------------------------------------------------------------")
    print(f"Model Performance for {target_column} using {model_type}:")
    print(f"{'Metric':<20}{'Value':<20}")
    print(f"{'-'*40}")
    print(f"{'Mean Squared Error (MSE)':<20}{mse:<20.4f}")
    print(f"{'Mean Absolute Error (MAE)':<20}{mae:<20.4f}")
    print(f"{'Root Mean Squared Error (RMSE)':<20}{rmse:<20.4f}")
    print(f"{'R-squared (R2)':<20}{r2:<20.4f}")

    # Display the selected features ordered by importance
    print(f'Selected Features for {target_column} (ordered by importance):')
    print(feature_importance_df)

    # Export the feature selector and the model
    joblib.dump(selector, f'feature_selector_{target_column}_{model_type}.joblib')
    joblib.dump(model, f'{model_type}_model_{target_column}.joblib')

    print(f"Feature selector and model for {target_column} using {model_type} have been saved.")

# %%
train_and_export_model('CPU Load_mean', model_type='linear', k_best_features=28)
train_and_export_model('CPU Load_mean', model_type='random_forest', k_best_features=28)
train_and_export_model('CPU Load_mean', model_type='svm', k_best_features=28)
train_and_export_model('CPU Load_mean', model_type='gradient_boosting', k_best_features=28)
train_and_export_model('CPU Load_mean', model_type='knn', k_best_features=28)
train_and_export_model('CPU Load_mean', model_type='decision_tree', k_best_features=28)
train_and_export_model('Memory Load_mean', model_type='linear', k_best_features=5)
train_and_export_model('Memory Load_mean', model_type='random_forest', k_best_features=5)
train_and_export_model('Memory Load_mean', model_type='svm', k_best_features=5)
train_and_export_model('Memory Load_mean', model_type='gradient_boosting', k_best_features=5)
train_and_export_model('Memory Load_mean', model_type='knn', k_best_features=5)
train_and_export_model('Memory Load_mean', model_type='decision_tree', k_best_features=5)
# Out:
# ------------------------------------------------------------
# Model Performance for CPU Load_mean using linear:
# Metric              Value
# ----------------------------------------
# Mean Squared Error (MSE)72.9020
# Mean Absolute Error (MAE)5.9235
# Root Mean Squared Error (RMSE)8.5383
# R-squared (R2)      0.6617
# Selected Features for CPU Load_mean (ordered by importance):
#                         Feature        Score
# 8    Memory Load_Individual_sum  8919.436149
# 27                    row_count  8916.560098
# 4       CPU Load_Individual_sum  8890.440518
# 26        Pricing_ PLATINUM_max  8501.974843
# 16           Pricing_ BASIC_sum  5167.828787
# 20            Pricing_ GOLD_sum  4559.721391
# 0              Elapsed Time_sum  4382.729573
# 24        Pricing_ PLATINUM_sum  3931.372684
# 2              Elapsed Time_max  3908.385197
# 12   Elapsed Time Deviation_sum  3155.165088
# 25       Pricing_ PLATINUM_mean  2873.410816
# 17          Pricing_ BASIC_mean  2837.748456
# 10   Memory Load_Individual_max  2743.344102
# 14   Elapsed Time Deviation_max  1920.083649
# 22            Pricing_ GOLD_max  1618.879838
# 6       CPU Load_Individual_max  1589.862158
# 19           Pricing_ BASIC_min  1582.145218
# 15   Elapsed Time Deviation_min  1530.029773
# 7       CPU Load_Individual_min  1496.941478
# 3              Elapsed Time_min  1179.022991
# 9   Memory Load_Individual_mean  1010.579593
# 1             Elapsed Time_mean   941.281664
# 21           Pricing_ GOLD_mean   574.748777
# 11   Memory Load_Individual_min   561.611409
# 13  Elapsed Time Deviation_mean   250.445331
# 5      CPU Load_Individual_mean   123.599051
# 18           Pricing_ BASIC_max   114.937162
# 23            Pricing_ GOLD_min   101.595454
# Feature selector and model for CPU Load_mean using linear have been saved.
# ------------------------------------------------------------
# Model Performance for CPU Load_mean using random_forest:
# Metric              Value
# ----------------------------------------
# Mean Squared Error (MSE)42.4741
# Mean Absolute Error (MAE)4.5498
# Root Mean Squared Error (RMSE)6.5172
# R-squared (R2)      0.8029
# Selected Features for CPU Load_mean (ordered by importance):
#                         Feature     Score
# 8    Memory Load_Individual_sum  0.411646
# 27                    row_count  0.399557
# 4       CPU Load_Individual_sum  0.396446
# 0              Elapsed Time_sum  0.384990
# 2              Elapsed Time_max  0.384751
# 16           Pricing_ BASIC_sum  0.325681
# 12   Elapsed Time Deviation_sum  0.323759
# 20            Pricing_ GOLD_sum  0.286825
# 23        Pricing_ PLATINUM_sum  0.267389
# 24       Pricing_ PLATINUM_mean  0.265867
# 25        Pricing_ PLATINUM_max  0.244780
# 17          Pricing_ BASIC_mean  0.234563
# 14   Elapsed Time Deviation_max  0.192791
# 10   Memory Load_Individual_max  0.172833
# 7       CPU Load_Individual_min  0.165041
# 21           Pricing_ GOLD_mean  0.151506
# 3              Elapsed Time_min  0.123136
# 9   Memory Load_Individual_mean  0.116328
# 1             Elapsed Time_mean  0.101619
# 15   Elapsed Time Deviation_min  0.096173
# 6       CPU Load_Individual_max  0.078713
# 22            Pricing_ GOLD_max  0.065155
# 13  Elapsed Time Deviation_mean  0.064334
# 19           Pricing_ BASIC_min  0.063309
# 5      CPU Load_Individual_mean  0.046929
# 11   Memory Load_Individual_min  0.029458
# 18           Pricing_ BASIC_max  0.005337
# 26            Pricing_ null_max  0.004389
# Feature selector and model for CPU Load_mean using random_forest have been saved.
# ------------------------------------------------------------
# Model Performance for CPU Load_mean using svm:
# Metric              Value
# ----------------------------------------
# Mean Squared Error (MSE)77.5969
# Mean Absolute Error (MAE)5.7372
# Root Mean Squared Error (RMSE)8.8089
# R-squared (R2)      0.6399
# Selected Features for CPU Load_mean (ordered by importance):
#                         Feature     Score
# 8    Memory Load_Individual_sum  0.411653
# 4       CPU Load_Individual_sum  0.397413
# 27                    row_count  0.391138
# 0              Elapsed Time_sum  0.385902
# 2              Elapsed Time_max  0.380454
# 16           Pricing_ BASIC_sum  0.333565
# 12   Elapsed Time Deviation_sum  0.322214
# 20            Pricing_ GOLD_sum  0.293073
# 23        Pricing_ PLATINUM_sum  0.261385
# 24       Pricing_ PLATINUM_mean  0.253437
# 25        Pricing_ PLATINUM_max  0.237114
# 17          Pricing_ BASIC_mean  0.232104
# 14   Elapsed Time Deviation_max  0.192795
# 7       CPU Load_Individual_min  0.162291
# 10   Memory Load_Individual_max  0.162074
# 21           Pricing_ GOLD_mean  0.152959
# 9   Memory Load_Individual_mean  0.117659
# 3              Elapsed Time_min  0.115997
# 1             Elapsed Time_mean  0.104133
# 6       CPU Load_Individual_max  0.102374
# 15   Elapsed Time Deviation_min  0.093448
# 19           Pricing_ BASIC_min  0.081708
# 22            Pricing_ GOLD_max  0.078936
# 13  Elapsed Time Deviation_mean  0.063323
# 5      CPU Load_Individual_mean  0.046326
# 11   Memory Load_Individual_min  0.043669
# 18           Pricing_ BASIC_max  0.007608
# 26            Pricing_ null_min  0.005268
# Feature selector and model for CPU Load_mean using svm have been saved.
# ------------------------------------------------------------
# Model Performance for CPU Load_mean using gradient_boosting:
# Metric              Value
# ----------------------------------------
# Mean Squared Error (MSE)40.7258
# Mean Absolute Error (MAE)4.4682
# Root Mean Squared Error (RMSE)6.3817
# R-squared (R2)      0.8110
# Selected Features for CPU Load_mean (ordered by importance):
#                         Feature     Score
# 8    Memory Load_Individual_sum  0.411186
# 27                    row_count  0.397523
# 4       CPU Load_Individual_sum  0.395183
# 0              Elapsed Time_sum  0.387147
# 2              Elapsed Time_max  0.383014
# 12   Elapsed Time Deviation_sum  0.323192
# 16           Pricing_ BASIC_sum  0.318445
# 19            Pricing_ GOLD_sum  0.293951
# 23        Pricing_ PLATINUM_sum  0.278881
# 24       Pricing_ PLATINUM_mean  0.267988
# 25        Pricing_ PLATINUM_max  0.251849
# 17          Pricing_ BASIC_mean  0.231740
# 14   Elapsed Time Deviation_max  0.190670
# 10   Memory Load_Individual_max  0.164399
# 7       CPU Load_Individual_min  0.161919
# 20           Pricing_ GOLD_mean  0.158784
# 3              Elapsed Time_min  0.125566
# 9   Memory Load_Individual_mean  0.115516
# 1             Elapsed Time_mean  0.101864
# 15   Elapsed Time Deviation_min  0.094670
# 6       CPU Load_Individual_max  0.072671
# 13  Elapsed Time Deviation_mean  0.064523
# 18           Pricing_ BASIC_min  0.059237
# 21            Pricing_ GOLD_max  0.049466
# 5      CPU Load_Individual_mean  0.043902
# 11   Memory Load_Individual_min  0.030416
# 26        Pricing_ PLATINUM_min  0.020478
# 22            Pricing_ GOLD_min  0.014928
# Feature selector and model for CPU Load_mean using gradient_boosting have been saved.
# ------------------------------------------------------------
# Model Performance for CPU Load_mean using knn:
# Metric              Value
# ----------------------------------------
# Mean Squared Error (MSE)61.2444
# Mean Absolute Error (MAE)5.3852
# Root Mean Squared Error (RMSE)7.8259
# R-squared (R2)      0.7158
# Selected Features for CPU Load_mean (ordered by importance):
#                         Feature     Score
# 8    Memory Load_Individual_sum  0.411939
# 27                    row_count  0.397662
# 4       CPU Load_Individual_sum  0.396691
# 0              Elapsed Time_sum  0.384781
# 2              Elapsed Time_max  0.384484
# 16           Pricing_ BASIC_sum  0.323582
# 12   Elapsed Time Deviation_sum  0.322561
# 19            Pricing_ GOLD_sum  0.281829
# 23       Pricing_ PLATINUM_mean  0.273139
# 22        Pricing_ PLATINUM_sum  0.265454
# 24        Pricing_ PLATINUM_max  0.238560
# 17          Pricing_ BASIC_mean  0.234414
# 14   Elapsed Time Deviation_max  0.192098
# 7       CPU Load_Individual_min  0.173353
# 10   Memory Load_Individual_max  0.156572
# 20           Pricing_ GOLD_mean  0.149943
# 3              Elapsed Time_min  0.124488
# 9   Memory Load_Individual_mean  0.117053
# 1             Elapsed Time_mean  0.102337
# 6       CPU Load_Individual_max  0.096141
# 15   Elapsed Time Deviation_min  0.095573
# 18           Pricing_ BASIC_min  0.071366
# 13  Elapsed Time Deviation_mean  0.062482
# 21            Pricing_ GOLD_max  0.050314
# 5      CPU Load_Individual_mean  0.046909
# 11   Memory Load_Individual_min  0.028788
# 25            Pricing_ null_max  0.007487
# 26            Pricing_ null_min  0.002470
# Feature selector and model for CPU Load_mean using knn have been saved.
# ------------------------------------------------------------
# Model Performance for CPU Load_mean using decision_tree:
# Metric              Value
# ----------------------------------------
# Mean Squared Error (MSE)80.5894
# Mean Absolute Error (MAE)6.2676
# Root Mean Squared Error (RMSE)8.9772
# R-squared (R2)      0.6260
# Selected Features for CPU Load_mean (ordered by importance):
#                         Feature     Score
# 8    Memory Load_Individual_sum  0.412571
# 27                    row_count  0.406700
# 4       CPU Load_Individual_sum  0.395258
# 0              Elapsed Time_sum  0.384693
# 2              Elapsed Time_max  0.378206
# 16           Pricing_ BASIC_sum  0.330799
# 12   Elapsed Time Deviation_sum  0.323213
# 20            Pricing_ GOLD_sum  0.295726
# 24       Pricing_ PLATINUM_mean  0.277571
# 23        Pricing_ PLATINUM_sum  0.275879
# 17          Pricing_ BASIC_mean  0.235459
# 25        Pricing_ PLATINUM_max  0.231738
# 14   Elapsed Time Deviation_max  0.192902
# 10   Memory Load_Individual_max  0.174726
# 7       CPU Load_Individual_min  0.160585
# 21           Pricing_ GOLD_mean  0.156057
# 3              Elapsed Time_min  0.123634
# 9   Memory Load_Individual_mean  0.117661
# 1             Elapsed Time_mean  0.103851
# 6       CPU Load_Individual_max  0.098816
# 15   Elapsed Time Deviation_min  0.095402
# 19           Pricing_ BASIC_min  0.064823
# 13  Elapsed Time Deviation_mean  0.063911
# 22            Pricing_ GOLD_max  0.063140
# 5      CPU Load_Individual_mean  0.048089
# 11   Memory Load_Individual_min  0.039896
# 18           Pricing_ BASIC_max  0.011863
# 26           Pricing_ null_mean  0.005084
# Feature selector and model for CPU Load_mean using decision_tree have been saved.
# ------------------------------------------------------------
# Model Performance for Memory Load_mean using linear:
# Metric              Value
# ----------------------------------------
# Mean Squared Error (MSE)0.0138
# Mean Absolute Error (MAE)0.0888
# Root Mean Squared Error (RMSE)0.1175
# R-squared (R2)      0.9165
# Selected Features for Memory Load_mean (ordered by importance):
#                       Feature         Score
# 2  Memory Load_Individual_sum  31354.047064
# 4                   row_count  31269.633623
# 1     CPU Load_Individual_sum  30678.169597
# 3       Pricing_ PLATINUM_max  21811.882305
# 0            Elapsed Time_sum  19277.773106
# Feature selector and model for Memory Load_mean using linear have been saved.
# ------------------------------------------------------------
# Model Performance for Memory Load_mean using random_forest:
# Metric              Value
# ----------------------------------------
# Mean Squared Error (MSE)0.0107
# Mean Absolute Error (MAE)0.0675
# Root Mean Squared Error (RMSE)0.1034
# R-squared (R2)      0.9354
# Selected Features for Memory Load_mean (ordered by importance):
#                       Feature     Score
# 0            Elapsed Time_sum  1.085595
# 1            Elapsed Time_max  0.907998
# 4  Elapsed Time Deviation_sum  0.884667
# 2     CPU Load_Individual_sum  0.871354
# 3  Memory Load_Individual_sum  0.869019
# Feature selector and model for Memory Load_mean using random_forest have been saved.
# ------------------------------------------------------------
# Model Performance for Memory Load_mean using svm:
# Metric              Value
# ----------------------------------------
# Mean Squared Error (MSE)0.0147
# Mean Absolute Error (MAE)0.0864
# Root Mean Squared Error (RMSE)0.1214
# R-squared (R2)      0.9109
# Selected Features for Memory Load_mean (ordered by importance):
#                       Feature     Score
# 0            Elapsed Time_sum  1.085390
# 1            Elapsed Time_max  0.908932
# 4  Elapsed Time Deviation_sum  0.884500
# 2     CPU Load_Individual_sum  0.871149
# 3  Memory Load_Individual_sum  0.867944
# Feature selector and model for Memory Load_mean using svm have been saved.
# ------------------------------------------------------------
# Model Performance for Memory Load_mean using gradient_boosting:
# Metric              Value
# ----------------------------------------
# Mean Squared Error (MSE)0.0104
# Mean Absolute Error (MAE)0.0666
# Root Mean Squared Error (RMSE)0.1020
# R-squared (R2)      0.9371
# Selected Features for Memory Load_mean (ordered by importance):
#                       Feature     Score
# 0            Elapsed Time_sum  1.085875
# 1            Elapsed Time_max  0.905116
# 4  Elapsed Time Deviation_sum  0.884582
# 2     CPU Load_Individual_sum  0.870949
# 3  Memory Load_Individual_sum  0.868738
# Feature selector and model for Memory Load_mean using gradient_boosting have been saved.
# ------------------------------------------------------------
# Model Performance for Memory Load_mean using knn:
# Metric              Value
# ----------------------------------------
# Mean Squared Error (MSE)0.0142
# Mean Absolute Error (MAE)0.0787
# Root Mean Squared Error (RMSE)0.1191
# R-squared (R2)      0.9142
# Selected Features for Memory Load_mean (ordered by importance):
#                       Feature     Score
# 0            Elapsed Time_sum  1.085571
# 1            Elapsed Time_max  0.906156
# 4  Elapsed Time Deviation_sum  0.884568
# 2     CPU Load_Individual_sum  0.871325
# 3  Memory Load_Individual_sum  0.869298
# Feature selector and model for Memory Load_mean using knn have been saved.
# ------------------------------------------------------------
# Model Performance for Memory Load_mean using decision_tree:
# Metric              Value
# ----------------------------------------
# Mean Squared Error (MSE)0.0195
# Mean Absolute Error (MAE)0.0871
# Root Mean Squared Error (RMSE)0.1395
# R-squared (R2)      0.8824
# Selected Features for Memory Load_mean (ordered by importance):
#                       Feature     Score
# 0            Elapsed Time_sum  1.085878
# 1            Elapsed Time_max  0.909765
# 4  Elapsed Time Deviation_sum  0.884668
# 2     CPU Load_Individual_sum  0.871020
# 3  Memory Load_Individual_sum  0.868608
# Feature selector and model for Memory Load_mean using decision_tree have been saved.
